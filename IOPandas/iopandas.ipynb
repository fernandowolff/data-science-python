# %%
import pandas as pd

# %% [markdown]
# # Leitura e Escrita de CSVs

# %%
url_mercado = "https://raw.githubusercontent.com/alura-cursos/pandas/main/superstore_data.csv"
dados_mercado = pd.read_csv(url_mercado)
dados_mercado
# Out:
#          Id  Year_Birth   Education Marital_Status   Income  Kidhome  \
# 0      1826        1970  Graduation       Divorced  84835.0        0
# 1         1        1961  Graduation         Single  57091.0        0
# 2     10476        1958  Graduation        Married  67267.0        0
# 3      1386        1967  Graduation       Together  32474.0        1
# 4      5371        1989  Graduation         Single  21474.0        1
# ...     ...         ...         ...            ...      ...      ...
# 2235  10142        1976         PhD       Divorced  66476.0        0
# 2236   5263        1977    2n Cycle        Married  31056.0        1
# 2237     22        1976  Graduation       Divorced  46310.0        1
# 2238    528        1978  Graduation        Married  65819.0        0
# 2239   4070        1969         PhD        Married  94871.0        0
#
#       Teenhome Dt_Customer  Recency  MntWines  ...  MntFishProducts  \
# 0            0   6/16/2014        0       189  ...              111
# ...

# %%
dados_mercado[['Id', 'Year_Birth', 'Income']]
# Out:
#          Id  Year_Birth   Income
# 0      1826        1970  84835.0
# 1         1        1961  57091.0
# 2     10476        1958  67267.0
# 3      1386        1967  32474.0
# 4      5371        1989  21474.0
# ...     ...         ...      ...
# 2235  10142        1976  66476.0
# 2236   5263        1977  31056.0
# 2237     22        1976  46310.0
# 2238    528        1978  65819.0
# 2239   4070        1969  94871.0
#
# [2240 rows x 3 columns]

# %%
dados_selecao = dados_mercado[['Id', 'Year_Birth', 'Income']]

# %%
dados_selecao.to_csv('dados_selecao.csv', index = False)

# %%
clientes_mercado = pd.read_csv('dados_selecao.csv')
clientes_mercado
# Out:
#          Id  Year_Birth   Income
# 0      1826        1970  84835.0
# 1         1        1961  57091.0
# 2     10476        1958  67267.0
# 3      1386        1967  32474.0
# 4      5371        1989  21474.0
# ...     ...         ...      ...
# 2235  10142        1976  66476.0
# 2236   5263        1977  31056.0
# 2237     22        1976  46310.0
# 2238    528        1978  65819.0
# 2239   4070        1969  94871.0
#
# [2240 rows x 3 columns]

# %% [markdown]
# # Leitura e Escrita de Planilhas

# %%
url_emissoes = './emissoes_CO2.xlsx'
dados_co2 = pd.read_excel(url_emissoes)

# %%
dados_co2.head()
# Out:
#           País ISO 3166-1 alpha-3   Ano  Total  Carvão  Oléo  Gás  Cimento  \
# 0  Afeganistão                AFG  1750    0.0     NaN   NaN  NaN      NaN
# 1  Afeganistão                AFG  1751    0.0     NaN   NaN  NaN      NaN
# 2  Afeganistão                AFG  1752    0.0     NaN   NaN  NaN      NaN
# 3  Afeganistão                AFG  1753    0.0     NaN   NaN  NaN      NaN
# 4  Afeganistão                AFG  1754    0.0     NaN   NaN  NaN      NaN
#
#    Queima  Outro  Per Capita
# 0     NaN    NaN         NaN
# 1     NaN    NaN         NaN
# 2     NaN    NaN         NaN
# 3     NaN    NaN         NaN
# 4     NaN    NaN         NaN

# %%
pd.ExcelFile(url_emissoes).sheet_names
# Out:
# ['emissoes_C02', 'emissoes_percapita', 'fontes']

# %%
percapita = pd.read_excel(url_emissoes, sheet_name='emissoes_percapita')
percapita.head()
# Out:
#           País ISO 3166-1 alpha-3   Ano  Total  Carvão  Óleo  Gás  Cimento  \
# 0  Afeganistão                AFG  1750    NaN     NaN   NaN  NaN      NaN
# 1  Afeganistão                AFG  1751    NaN     NaN   NaN  NaN      NaN
# 2  Afeganistão                AFG  1752    NaN     NaN   NaN  NaN      NaN
# 3  Afeganistão                AFG  1753    NaN     NaN   NaN  NaN      NaN
# 4  Afeganistão                AFG  1754    NaN     NaN   NaN  NaN      NaN
#
#    Queima  Outro
# 0     NaN    NaN
# 1     NaN    NaN
# 2     NaN    NaN
# 3     NaN    NaN
# 4     NaN    NaN

# %%
fontes = pd.read_excel(url_emissoes, sheet_name='fontes')
fontes.head()
# Out:
#           País ISO 3166-1 alpha-3   Ano   Total  Carvão    Oléo     Gás  \
# 0  Afeganistão                AFG  1750  [NONE]  [NONE]  [NONE]  [NONE]
# 1  Afeganistão                AFG  1751  [NONE]  [NONE]  [NONE]  [NONE]
# 2  Afeganistão                AFG  1752  [NONE]  [NONE]  [NONE]  [NONE]
# 3  Afeganistão                AFG  1753  [NONE]  [NONE]  [NONE]  [NONE]
# 4  Afeganistão                AFG  1754  [NONE]  [NONE]  [NONE]  [NONE]
#
#   Cimento  Queima   Outro Per Capita
# 0  [NONE]  [NONE]  [NONE]     [NONE]
# 1  [NONE]  [NONE]  [NONE]     [NONE]
# 2  [NONE]  [NONE]  [NONE]     [NONE]
# 3  [NONE]  [NONE]  [NONE]     [NONE]
# 4  [NONE]  [NONE]  [NONE]     [NONE]

# %%
intervalo = pd.read_excel(url_emissoes, sheet_name='emissoes_C02', usecols='A:D')
intervalo
# Out:
#               País ISO 3166-1 alpha-3   Ano         Total
# 0      Afeganistão                AFG  1750  0.000000e+00
# 1      Afeganistão                AFG  1751  0.000000e+00
# 2      Afeganistão                AFG  1752  0.000000e+00
# 3      Afeganistão                AFG  1753  0.000000e+00
# 4      Afeganistão                AFG  1754  0.000000e+00
# ...            ...                ...   ...           ...
# 63099       Global                WLD  2017  3.609674e+10
# 63100       Global                WLD  2018  3.682651e+10
# 63101       Global                WLD  2019  3.708256e+10
# 63102       Global                WLD  2020  3.526409e+10
# 63103       Global                WLD  2021  3.712385e+10
#
# [63104 rows x 4 columns]

# %%
intervalo_2 = pd.read_excel(url_emissoes, sheet_name='emissoes_C02', usecols='A:D', nrows=10)
intervalo_2
# Out:
#           País ISO 3166-1 alpha-3   Ano  Total
# 0  Afeganistão                AFG  1750      0
# 1  Afeganistão                AFG  1751      0
# 2  Afeganistão                AFG  1752      0
# 3  Afeganistão                AFG  1753      0
# 4  Afeganistão                AFG  1754      0
# 5  Afeganistão                AFG  1755      0
# 6  Afeganistão                AFG  1756      0
# 7  Afeganistão                AFG  1757      0
# 8  Afeganistão                AFG  1758      0
# 9  Afeganistão                AFG  1759      0

# %%
percapita.to_excel('c02_percapita.xlsx', index=False)

# %%
pd.read_excel('c02_percapita.xlsx')
# Out:
#               País ISO 3166-1 alpha-3   Ano      Total     Carvão       Óleo  \
# 0      Afeganistão                AFG  1750        NaN        NaN        NaN
# 1      Afeganistão                AFG  1751        NaN        NaN        NaN
# 2      Afeganistão                AFG  1752        NaN        NaN        NaN
# 3      Afeganistão                AFG  1753        NaN        NaN        NaN
# 4      Afeganistão                AFG  1754        NaN        NaN        NaN
# ...            ...                ...   ...        ...        ...        ...
# 63099       Global                WLD  2017  4749682.0  1908857.0  1610910.0
# 63100       Global                WLD  2018  4792753.0  1919213.0  1596350.0
# 63101       Global                WLD  2019  4775633.0  1896468.0  1589920.0
# 63102       Global                WLD  2020  4497423.0  1807760.0  1427353.0
# 63103       Global                WLD  2021  4693699.0  1893923.0  1496614.0
#
#              Gás   Cimento   Queima    Outro
# ...

# %% [markdown]
# # Lendo dados do Google Sheets
# As strings 'gviz/tq' vão permitir acesso à API de visualização de dados do google.
#
# O parâmetro 'tqx=out:csv' define que o formato retornado será em CSV.
#
# O parâmetro 'sheet' fará com que todos os dados da planilha sejam retornados, incluindo cabeçalhos, linhas, colunas, etc.

# %%
sheet_id = '1lzq0k-41-MbbS63C3Q9i1wPvLkSJt9zhr4Jolt1vEog'
url_sheets = f'https://docs.google.com/spreadsheets/d/{sheet_id}/gviz/tq?tqx=out:csv&sheet'

# %%
dados_co2_sheets = pd.read_csv(url_sheets) # isso vai retornar a primeira página do documento

# %%
sheet_name = 'emissoes_percapita'
url_percapita = f'https://docs.google.com/spreadsheets/d/{sheet_id}/gviz/tq?tqx=out:csv&sheet={sheet_name}'

# %%
percapita_sheets = pd.read_csv(url_percapita)

# %%
sheet_name = 'fontes'
url_fontes = f'https://docs.google.com/spreadsheets/d/{sheet_id}/gviz/tq?tqx=out:csv&sheet={sheet_name}'

# %%
fontes_sheets = pd.read_csv(url_fontes)

# %% [markdown]
# ## Exercício Google Sheets

# %%
google_sheets_url = f'https://docs.google.com/spreadsheets/d/1pvBoLyX8kP0TjtUbadVMGdTl4yzm6bHMThhPiqCVtpw/gviz/tq?tqx=out:csv&sheet'
dados_google_sheets = pd.read_csv(google_sheets_url)
dados_google_sheets.head()
# Out:
#        Country country_code                     Region  \
# 0        Aruba          ABW  Latin America & Caribbean
# 1  Afghanistan          AFG                 South Asia
# 2       Angola          AGO         Sub-Saharan Africa
# 3      Albania          ALB      Europe & Central Asia
# 4      Andorra          AND      Europe & Central Asia
#
#                            Indicator Name           1990         1991  \
# 0  CO2 emissions (metric tons per capita)            NaN          NaN
# 1  CO2 emissions (metric tons per capita)    191.745.115  167.681.579
# 2  CO2 emissions (metric tons per capita)    553.661.955  544.538.649
# 3  CO2 emissions (metric tons per capita)  1.819.541.634  124.281.022
# 4  CO2 emissions (metric tons per capita)  7.521.831.658  723.537.924
#
#           1992           1993           1994           1995  ...  \
# 0          NaN            NaN            NaN            NaN  ...
# 1   95.957.742      8.472.111     75.545.827     68.467.956  ...
# ...

# %%
dados_google_sheets.shape
# Out:
# (215, 35)

# %%
dados_google_sheets.to_csv('dados_google_sheets.csv', index=False)

# %% [markdown]
# # Lendo e Escrevendo Arquivos JSON

# %%
dados_pacientes = pd.read_json('./pacientes.json')
dados_pacientes

# %%
dados_pacientes2 = pd.read_json('https://raw.githubusercontent.com/alura-cursos/Pandas/main/pacientes_2.json')
dados_pacientes2
# Out:
#                                     Pesquisa   Ano  \
# 0  Principais Indicadores de Doenca Cardiaca  2020
# 1  Principais Indicadores de Doenca Cardiaca  2020
# 2  Principais Indicadores de Doenca Cardiaca  2020
#
#                                            Pacientes
# 0  {'ID': '01', 'Faixa_etaria': '55-59', 'Sexo_bi...
# 1  {'ID': '02', 'Faixa_etaria': '80 ou +', 'Sexo_...
# 2  {'ID': '03', 'Faixa_etaria': '65-69', 'Sexo_bi...

# %%
pd.json_normalize(dados_pacientes2)
# Out:
# Empty DataFrame
# Columns: []
# Index: [0, 1, 2]

# %%
dados_pacientes_normalizados = pd.json_normalize(dados_pacientes2['Pacientes']) # Transforma uma coluna com valores json num DataSet
dados_pacientes_normalizados
# Out:
#    ID Faixa_etaria Sexo_biologico    Raça    IMC Fumante Consumo_alcool  \
# 0  01        55-59       Feminino  Branca  16.60     Sim            Nao
# 1  02      80 ou +       Feminino  Branca  20.34     Nao            Nao
# 2  03        65-69      Masculino  Branca  26.58     Sim            Nao
#
#    Saude_fisica  Saude_mental Dificuldade_caminhar Atividade_fisica  \
# 0             3            30                  Nao              Sim
# 1             0             0                  Nao              Sim
# 2            20            30                  Nao              Sim
#
#   Saude_geral  Horas_sono                Problemas_saude
# 0   Muito boa           5  [Diabetes, Asma, Cancer_pele]
# 1   Muito boa           7                          [AVC]
# 2   Muito boa           8               [diabetes, Asma]

# %%
dados_pacientes_normalizados2 = pd.json_normalize(dados_pacientes2, record_path=['Pacientes']) # Mesmo efeito do código acima
dados_pacientes_normalizados2
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 dados_pacientes_normalizados2 = pd.json_normalize(dados_pacientes2, record_path=['Pacientes']) # Mesmo efeito do código acima
#       2 dados_pacientes_normalizados2
#
# File ~/anaconda3/envs/datasciencepython/lib/python3.12/site-packages/pandas/io/json/_normalize.py:517, in json_normalize(data, record_path, meta, meta_prefix, record_prefix, errors, sep, max_level)
#     514                 meta_vals[key].append(meta_val)
#     515             records.extend(recs)
# --> 517 _recursive_extract(data, record_path, {}, level=0)
#     519 result = DataFrame(records)
#     521 if record_prefix is not None:
#
# File ~/anaconda3/envs/datasciencepython/lib/python3.12/site-packages/pandas/io/json/_normalize.py:499, in json_normalize.<locals>._recursive_extract(data, path, seen_meta, level)
#     497 else:
# ...

# %%
dados_pacientes_normalizados3 = pd.json_normalize(dados_pacientes2, record_path=['Pacientes'], meta=['Pesquisa', 'Ano']) # Mesmo efeito do código acima mas incluindo valores do nvl superior a 'Pacientes'.
dados_pacientes_normalizados3
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 dados_pacientes_normalizados3 = pd.json_normalize(dados_pacientes2, record_path=['Pacientes'], meta=['Pesquisa', 'Ano']) # Mesmo efeito do código acima mas incluindo valores do nvl superior a 'Pacientes'.
#       2 dados_pacientes_normalizados3
#
# File ~/anaconda3/envs/datasciencepython/lib/python3.12/site-packages/pandas/io/json/_normalize.py:517, in json_normalize(data, record_path, meta, meta_prefix, record_prefix, errors, sep, max_level)
#     514                 meta_vals[key].append(meta_val)
#     515             records.extend(recs)
# --> 517 _recursive_extract(data, record_path, {}, level=0)
#     519 result = DataFrame(records)
#     521 if record_prefix is not None:
#
# ...

# %% [markdown]
# A função json_normalize() aceita apenas um dicionário ou uma lista de dicionários. Por isso, no vídeo foi usada a estratégia de usar o código: pd.json_normalize(dados_pacientes_2['Pacientes']).
#
# Porém, se tentarmos usar parâmetros da função json_normalize em um arquivo JSON podem surgir erros.
#
# Para contornar isso, precisamos importar o módulo json e ler os arquivos conforme o código abaixo:

# %%
import json

# %%
with open('pacientes_2.json', 'r') as f:
    dados_pacientes = json.loads(f.read())

dados_pacientes_normalizados4 = pd.json_normalize(dados_pacientes, record_path='Pacientes', meta=['Pesquisa', 'Ano'])
dados_pacientes_normalizados4
# Out:
#    ID Faixa_etaria Sexo_biologico    Raça    IMC Fumante Consumo_alcool  \
# 0  01        55-59       Feminino  Branca  16.60     Sim            Nao
# 1  02      80 ou +       Feminino  Branca  20.34     Nao            Nao
# 2  03        65-69      Masculino  Branca  26.58     Sim            Nao
#
#    Saude_fisica  Saude_mental Dificuldade_caminhar Atividade_fisica  \
# 0             3            30                  Nao              Sim
# 1             0             0                  Nao              Sim
# 2            20            30                  Nao              Sim
#
#   Saude_geral  Horas_sono                Problemas_saude  \
# 0   Muito boa           5  [Diabetes, Asma, Cancer_pele]
# 1   Muito boa           7                          [AVC]
# 2   Muito boa           8               [diabetes, Asma]
#
#                                     Pesquisa   Ano
# 0  Principais Indicadores de Doenca Cardiaca  2020
# 1  Principais Indicadores de Doenca Cardiaca  2020
# ...

# %%
dados_pacientes_normalizados4.to_json('pacientes_normalizados.json')

# %%
dados_pacientes_teste = pd.read_json('pacientes_normalizados.json')
dados_pacientes_teste
# Out:
#    ID Faixa_etaria Sexo_biologico    Raça    IMC Fumante Consumo_alcool  \
# 0   1        55-59       Feminino  Branca  16.60     Sim            Nao
# 1   2      80 ou +       Feminino  Branca  20.34     Nao            Nao
# 2   3        65-69      Masculino  Branca  26.58     Sim            Nao
#
#    Saude_fisica  Saude_mental Dificuldade_caminhar Atividade_fisica  \
# 0             3            30                  Nao              Sim
# 1             0             0                  Nao              Sim
# 2            20            30                  Nao              Sim
#
#   Saude_geral  Horas_sono                Problemas_saude  \
# 0   Muito boa           5  [Diabetes, Asma, Cancer_pele]
# 1   Muito boa           7                          [AVC]
# 2   Muito boa           8               [diabetes, Asma]
#
#                                     Pesquisa   Ano
# 0  Principais Indicadores de Doenca Cardiaca  2020
# 1  Principais Indicadores de Doenca Cardiaca  2020
# ...

# %% [markdown]
# # Lendo e Escrevendo HTML

# %%
movies_html = pd.read_html('movies.html')
movies_html
# Out:
# [       0                      1
#  0   1998             100 Movies
#  1   1999              100 Stars
#  2   2000             100 Laughs
#  3   2001            100 Thrills
#  4   2002           100 Passions
#  5   2003  100 Heroes & Villains
#  6   2004              100 Songs
#  7   2005       100 Movie Quotes
#  8   2005              25 Scores
#  9   2006             100 Cheers
#  10  2006            25 Musicals
#  11  2007   100 Movies (Updated)
#  12  2008        AFI's 10 Top 10
#  13   vte                    vte,
#                        Film  Release year              Director  \
#  0             Citizen Kane          1941          Orson Welles
#  1               Casablanca          1942        Michael Curtiz
#  2            The Godfather          1972  Francis Ford Coppola
#  3       Gone with the Wind          1939        Victor Fleming
#  4       Lawrence of Arabia          1962            David Lean
#  ..                     ...           ...                   ...
# ...

# %%
type(movies_html)
# Out:
# list

# %%
len(movies_html)
# Out:
# 2

# %%
movies_100 = movies_html[1]
movies_100
# Out:
#                       Film  Release year              Director  \
# 0             Citizen Kane          1941          Orson Welles
# 1               Casablanca          1942        Michael Curtiz
# 2            The Godfather          1972  Francis Ford Coppola
# 3       Gone with the Wind          1939        Victor Fleming
# 4       Lawrence of Arabia          1962            David Lean
# ..                     ...           ...                   ...
# 118        Sophie's Choice          1982        Alan J. Pakula
# 119  The Last Picture Show          1971     Peter Bogdanovich
# 120     Do the Right Thing          1989             Spike Lee
# 121           Blade Runner          1982          Ridley Scott
# 122              Toy Story          1995         John Lasseter
#
#                               Production companies 1998 Rank 2007 Rank
# 0                               RKO Radio Pictures         1         1
# ...

# %%
movies_100.to_html("topfilmes.html")

# %% [markdown]
# # Lendo e Escrevendo XML

# %%
dados_imdb = pd.read_xml('https://raw.githubusercontent.com/alura-cursos/Pandas/main/imdb_top_1000.xml')
dados_imdb.head()
# Out:
#    index                                        Poster_Link  \
# 0      0  https://m.media-amazon.com/images/M/MV5BMDFkYT...
# 1      1  https://m.media-amazon.com/images/M/MV5BM2MyNj...
# 2      2  https://m.media-amazon.com/images/M/MV5BMTMxNT...
# 3      3  https://m.media-amazon.com/images/M/MV5BMWMwMG...
# 4      4  https://m.media-amazon.com/images/M/MV5BMWU4N2...
#
#                Series_Title Released_Year Certificate  Runtime  \
# 0  The Shawshank Redemption          1994           A  142 min
# 1             The Godfather          1972           A  175 min
# 2           The Dark Knight          2008          UA  152 min
# 3    The Godfather: Part II          1974           A  202 min
# 4              12 Angry Men          1957           U   96 min
#
#                   Genre  IMDB_Rating  \
# 0                 Drama          9.3
# 1          Crime, Drama          9.2
# 2  Action, Crime, Drama          9.0
# 3          Crime, Drama          9.0
# ...

# %%
dados_imdb.to_xml('movies_mdb.xml')

# %% [markdown]
# # Banco de Dados

# %%
import sqlalchemy

# %%
sqlalchemy.__version__
# Out:
# '2.0.29'

# %%
from sqlalchemy import create_engine, MetaData, Table, inspect

# %%
engine = create_engine('sqlite:///:memory:')

# %%
clientes_banco = pd.read_csv('https://raw.githubusercontent.com/alura-cursos/Pandas/main/clientes_banco.csv')
clientes_banco.head()
# Out:
#    ID_Cliente  Idade Grau_escolaridade   Estado_civil  Tamanho_familia  \
# 0     5008804     32   Ensino superior  União-estável                2
# 1     5008805     32   Ensino superior  União-estável                2
# 2     5008806     58      Ensino médio         Casado                2
# 3     5008808     52      Ensino médio       Solteiro                1
# 4     5008809     52      Ensino médio       Solteiro                1
#
#     Categoria_de_renda   Ocupacao  Anos_empregado  Rendimento_anual  \
# 0            Empregado      Outro              12          427500.0
# 1            Empregado      Outro              12          427500.0
# 2            Empregado  Segurança               3          112500.0
# 3  Associado comercial     Vendas               8          270000.0
# 4  Associado comercial     Vendas               8          270000.0
#
#    Tem_carro                   Moradia
# 0          1       Apartamento alugado
# 1          1       Apartamento alugado
# ...

# %%
clientes_banco.to_sql('clientes', engine, index=False)
# Out:
# 438463

# %%
inspector = inspect(engine)

# %%
print(inspector.get_table_names())
# Out:
# ['clientes']

# %%
query = "select * from clientes where [Categoria_de_renda] = 'Empregado'"

# %%
empregados = pd.read_sql(query, engine)
empregados
# Out:
#         ID_Cliente  Idade Grau_escolaridade   Estado_civil  Tamanho_familia  \
# 0          5008804     32   Ensino superior  União-estável                2
# 1          5008805     32   Ensino superior  União-estável                2
# 2          5008806     58      Ensino médio         Casado                2
# 3          5008815     46   Ensino superior         Casado                2
# 4          5112956     46   Ensino superior         Casado                2
# ...            ...    ...               ...            ...              ...
# 226054     6837905     43      Ensino médio         Casado                3
# 226055     6837906     43      Ensino médio         Casado                3
# 226056     6839936     34      Ensino médio         Casado                3
# 226057     6840222     43      Ensino médio       Solteiro                1
# 226058     6842885     51      Ensino médio         Casado                2
#
# ...

# %%
empregados.to_sql('empregados', con=engine, index=False)
# Out:
# 226059

# %%
pd.read_sql_table('empregados', engine)
# Out:
#         ID_Cliente  Idade Grau_escolaridade   Estado_civil  Tamanho_familia  \
# 0          5008804     32   Ensino superior  União-estável                2
# 1          5008805     32   Ensino superior  União-estável                2
# 2          5008806     58      Ensino médio         Casado                2
# 3          5008815     46   Ensino superior         Casado                2
# 4          5112956     46   Ensino superior         Casado                2
# ...            ...    ...               ...            ...              ...
# 226054     6837905     43      Ensino médio         Casado                3
# 226055     6837906     43      Ensino médio         Casado                3
# 226056     6839936     34      Ensino médio         Casado                3
# 226057     6840222     43      Ensino médio       Solteiro                1
# 226058     6842885     51      Ensino médio         Casado                2
#
# ...

# %%
pd.read_sql_table('empregados', engine, columns=['ID_Cliente', 'Grau_escolaridade', 'Rendimento_anual'])
# Out:
#         ID_Cliente Grau_escolaridade  Rendimento_anual
# 0          5008804   Ensino superior          427500.0
# 1          5008805   Ensino superior          427500.0
# 2          5008806      Ensino médio          112500.0
# 3          5008815   Ensino superior          270000.0
# 4          5112956   Ensino superior          270000.0
# ...            ...               ...               ...
# 226054     6837905      Ensino médio          355050.0
# 226055     6837906      Ensino médio          355050.0
# 226056     6839936      Ensino médio          135000.0
# 226057     6840222      Ensino médio          103500.0
# 226058     6842885      Ensino médio          121500.0
#
# [226059 rows x 3 columns]

# %%
query2 = "select * from clientes"
pd.read_sql(query2, engine)
# Out:
#         ID_Cliente  Idade Grau_escolaridade   Estado_civil  Tamanho_familia  \
# 0          5008804     32   Ensino superior  União-estável                2
# 1          5008805     32   Ensino superior  União-estável                2
# 2          5008806     58      Ensino médio         Casado                2
# 3          5008808     52      Ensino médio       Solteiro                1
# 4          5008809     52      Ensino médio       Solteiro                1
# ...            ...    ...               ...            ...              ...
# 438458     6840104     62      Ensino médio     Divorciado                1
# 438459     6840222     43      Ensino médio       Solteiro                1
# 438460     6841878     22   Ensino superior       Solteiro                1
# 438461     6842765     59      Ensino médio         Casado                2
# 438462     6842885     51      Ensino médio         Casado                2
#
# ...

# %%
query3 = "delete from clientes where [ID_Cliente] = 5008804"
with engine.connect() as conn:
    conn.execute(query3)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# File ~/anaconda3/envs/datasciencepython/lib/python3.12/site-packages/sqlalchemy/engine/base.py:1418, in Connection.execute(self, statement, parameters, execution_options)
#    1417 try:
# -> 1418     meth = statement._execute_on_connection
#    1419 except AttributeError as err:
#
# AttributeError: 'str' object has no attribute '_execute_on_connection'
#
# The above exception was the direct cause of the following exception:
#
# ObjectNotExecutableError                  Traceback (most recent call last)
# Cell In[30], line 3
#       1 query3 = "delete from clientes where [ID_Cliente] = 5008804"
#       2 with engine.connect() as conn:
# ----> 3     conn.execute(query3)
#
# ...

# %%
query4 = "update clientes set [Grau_escolaridade] = 'Ensino superior' where [ID_Cliente] = 5008808"
with engine.connect() as conn:
    conn.execute(query4)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# File ~/anaconda3/envs/datasciencepython/lib/python3.12/site-packages/sqlalchemy/engine/base.py:1418, in Connection.execute(self, statement, parameters, execution_options)
#    1417 try:
# -> 1418     meth = statement._execute_on_connection
#    1419 except AttributeError as err:
#
# AttributeError: 'str' object has no attribute '_execute_on_connection'
#
# The above exception was the direct cause of the following exception:
#
# ObjectNotExecutableError                  Traceback (most recent call last)
# Cell In[29], line 3
#       1 query4 = "update clientes set Grau_escolaridade = 'Ensino superior' where ID_Cliente = 5008808"
#       2 with engine.connect() as conn:
# ----> 3     conn.execute(query4)
#
# ...
